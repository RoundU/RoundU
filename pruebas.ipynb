# %%
import pandas as pd

# %%
df = pd.read_json("data/stream_barcelona.json", lines=True)
df.shape
# Out:
# (12664, 36)

# %%
df.iloc[1]["user"]
# Out:
# {'id': 574637350,
#  'id_str': '574637350',
#  'name': 'JaimeLT',
#  'screen_name': 'JaimeLujan2001',
#  'location': 'Puertollano, España',
#  'url': None,
#  'description': '/Un chico cualquiera/ Amante de los videojuegos y de los zorros/Icon by @middymidmid',
#  'translator_type': 'regular',
#  'protected': False,
#  'verified': False,
#  'followers_count': 161,
#  'friends_count': 617,
#  'listed_count': 2,
#  'favourites_count': 1818,
#  'statuses_count': 5140,
#  'created_at': 'Tue May 08 17:12:36 +0000 2012',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': 'es',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#  'profile_background_tile': False,
#  'profile_link_color': 'FF691F',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1047855593388756993/lr9gHNbp_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1047855593388756993/lr9gHNbp_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/574637350/1525876663',
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %%
df.iloc[2].user["location"]
# Out:
# 'Lagos, Nigeria'

# %%
def filtro(x):
    timestamp = x["created_at"]
    msg_id = x["id"]
    loc = x["user"]["location"]
    return timestamp, ("id: ", msg_id), ("loc: ", loc)

# %%
filtro(df.iloc[0])
# Out:
# (Timestamp('2019-04-02 15:35:56'),
#  ('id: ', 1113102772923183104),
#  ('loc: ', 'Barcelona, España'))

# %%
a = pd.read_json("data/stream_madrid.json", lines=True)

# %%
df.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'extended_tweet', 'favorite_count',
#        'favorited', 'filter_level', 'geo', 'id', 'id_str',
#        'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'place',
#        'possibly_sensitive', 'quote_count', 'quoted_status',
#        'quoted_status_id', 'quoted_status_id_str', 'quoted_status_permalink',
#        'reply_count', 'retweet_count', 'retweeted', 'retweeted_status',
#        'source', 'text', 'timestamp_ms', 'truncated', 'user'],
#       dtype='object')

# %%
for index,i in enumerate([100,20,10]):
    print(i)
# Out:
# 100
# 20
# 10

# %%
for index,i in enumerate(df["text"]):
    if "RT @" not in i:
        if df.iloc[index]["truncated"] == True:
            print(index)
# Out:
# 4
# 5
# 14
# 18
# 20
# 25
# 39
# 45
# 48
# 50
# 53
# 57
# 59
# 62
# 73
# 87
# 88
# 99
# 106
# 126
# 129
# 139
# 142
# 145
# 152
# 161
# 165
# 166
# 169
# 173
# 180
# 186
# 193
# 194
# 223
# 224
# 232
# 234
# 243
# 246
# 274
# 278
# 282
# 285
# 290
# 298
# 299
# 305
# 306
# 309
# 315
# 321
# 328
# 330
# 334
# 340
# 351
# 358
# 359
# 372
# 373
# 379
# 386
# 399
# 402
# 405
# 406
# 412
# 427
# 435
# 436
# 446
# 460
# 463
# 475
# 494
# 495
# 502
# 507
# 508
# 511
# 524
# 530
# 552
# 558
# 575
# 576
# 584
# 591
# 593
# 601
# 610
# 612
# 619
# 627
# 641
# 644
# 656
# 664
# 665
# 680
# 682
# 688
# 689
# 702
# 11243
# 11244
# 11245
# 11249
# 11255
# 11266
# 11280
# 11292
# 11300
# 11303
# 11309
# 11310
# 11333
# 11335
# 11343
# 11365
# 11370
# 11371
# 11384
# 11388
# 11394
# 11397
# 11414
# 11421
# 11443
# 11450
# 11455
# 11456
# 11460
# 11467
# 11470
# 11473
# 11476
# 11477
# 11482
# 11492
# 11494
# 11499
# 11505
# 11521
# 11522
# 11523
# 11539
# 11541
# 11549
# 11554
# 11556
# 11566
# 11567
# 11581
# 11584
# 11595
# 11607
# 11608
# 11648
# 11654
# 11658
# 11667
# 11675
# 11677
# 11684
# 11685
# 11687
# 11747
# 11755
# 11759
# 11761
# 11766
# 11779
# 11792
# 11799
# 11809
# 11818
# 11828
# 11833
# 11848
# 11854
# 11855
# 11865
# 11867
# 11870
# 11881
# 11888
# 11890
# 11892
# 11898
# 11899
# 11904
# 11909
# 11916
# 11917
# 11954
# 11956
# 11962
# 11970
# 11999
# 12003
# 12004
# 12009
# 12014
# 12021
# 12026
# 12027
# 12028
# 12043
# 12047
# 12054
# 12059
# 12067
# 12071
# 12075
# 12079
# 12087
# 12096
# 12099
# 12107
# 12111
# 12118
# 12123
# 12130
# 12138
# 12144
# 12146
# 12148
# 12151
# 12154
# 12166
# 12172
# 12173
# 12184
# 12189
# 12190
# 12192
# 12194
# 12207
# 12210
# 12212
# 12222
# 12235
# 12239
# 12242
# 12244
# 12263
# 12275
# 12276
# 12277
# 12280
# 12303
# 12312
# 12315
# 12327
# 12334
# 12341
# 12343
# 12351
# 12364
# 12368
# 12380
# 12385
# 12392
# 12416
# 12417
# 12422
# 12423
# 12438
# 12457
# 12460
# 12463
# 12468
# 12477
# 12485
# 12489
# 12506
# 12521
# 12526
# 12568
# 12580
# 12590
# 12595
# 12604
# 12605
# 12607
# 12610
# 12614
# 12615
# 12616
# 12620
# 12623
# 12645
# 12652
# 12653

# %%
tw = df.iloc[4]
tw
# Out:
# contributors                                                               NaN
# coordinates                                                               None
# created_at                                                 2019-04-02 15:36:00
# display_text_range                                                    [0, 140]
# entities                     {'hashtags': [{'text': 'LaLiga', 'indices': [1...
# extended_entities                                                          NaN
# extended_tweet               {'full_text': '[#LaLiga 🇪🇸] La forme de Lionel...
# favorite_count                                                               0
# favorited                                                                False
# filter_level                                                               low
# geo                                                                       None
# id                                                         1113102791067795457
# id_str                                                     1113102791067795456
# in_reply_to_screen_name                                                   None
# in_reply_to_status_id                                                      NaN
# in_reply_to_status_id_str                                                  NaN
# in_reply_to_user_id                                                        NaN
# in_reply_to_user_id_str                                                    NaN
# is_quote_status                                                          False
# lang                                                                        fr
# place                                                                     None
# possibly_sensitive                                                           0
# quote_count                                                                  0
# quoted_status                                                              NaN
# quoted_status_id                                                           NaN
# quoted_status_id_str                                                       NaN
# quoted_status_permalink                                                    NaN
# reply_count                                                                  0
# retweet_count                                                                0
# retweeted                                                                False
# retweeted_status                                                           NaN
# source                       <a href="https://about.twitter.com/products/tw...
# text                         [#LaLiga 🇪🇸] La forme de Lionel #Messi avec le...
# timestamp_ms                                        2019-04-02 15:36:00.497000
# truncated                                                                 True
# user                         {'id': 936233026660511744, 'id_str': '93623302...
# Name: 4, dtype: object

# %%
if "RT @" in tw["text"]:
    print("retweet o respuesta")
    print(tw["text"])
    print(tw["retweeted_status"])
# Out:
# retweet o respuesta
# RT @XTNVillanueva: Tengo el corazón en un puño, necesito TODA LA AYUDA POSIBLE, mi tía ha desaparecido en Barcelona, por favor, dad RT 😢
# Má…
# {'created_at': 'Mon Apr 01 06:25:29 +0000 2019', 'id': 1112601860781887489, 'id_str': '1112601860781887489', 'text': 'Tengo el corazón en un puño, necesito TODA LA AYUDA POSIBLE, mi tía ha desaparecido en Barcelona, por favor, dad RT… https://t.co/a9ggLWS6AI', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 116039983, 'id_str': '116039983', 'name': 'Christian Villanueva', 'screen_name': 'XTNVillanueva', 'location': 'Barcelona / Madrid', 'url': 'http://bit.ly/XTNVillanuevaYT', 'description': 'Cantante, compositor y creador de contenido.\nDeja que la música suene 😉 \nContacto: christianvillanueva@bigcreators.es', 'translator_type': 'regular', 'protected': False, 'verified': False, 'followers_count': 43466, 'friends_count': 652, 'listed_count': 112, 'favourites_count': 762, 'statuses_count': 37362, 'created_at': 'Sat Feb 20 23:02:57 +0000 2010', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme7/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme7/bg.gif', 'profile_background_tile': True, 'profile_link_color': 'B40404', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '5E0A2C', 'profile_use_background_image': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1110625734211633153/KyFg7PAp_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1110625734211633153/KyFg7PAp_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/116039983/1487619578', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Tengo el corazón en un puño, necesito TODA LA AYUDA POSIBLE, mi tía ha desaparecido en Barcelona, por favor, dad RT 😢\nMás info: https://t.co/7PNESO7J2Z https://t.co/sIT7tROGdS', 'display_text_range': [0, 151], 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/7PNESO7J2Z', 'expanded_url': 'https://www.elperiodico.com/es/sociedad/20190330/desaparecida-una-mujer-en-barcelona-desde-el-martes-7382141?utm_source=twitter&utm_medium=social&utm_campaign=cm', 'display_url': 'elperiodico.com/es/sociedad/20…', 'indices': [128, 151]}], 'user_mentions': [], 'symbols': [], 'media': [{'id': 1112601850530930689, 'id_str': '1112601850530930689', 'indices': [152, 175], 'media_url': 'http://pbs.twimg.com/media/D3DBfP1WoAE7uNY.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D3DBfP1WoAE7uNY.jpg', 'url': 'https://t.co/sIT7tROGdS', 'display_url': 'pic.twitter.com/sIT7tROGdS', 'expanded_url': 'https://twitter.com/XTNVillanueva/status/1112601860781887489/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1186, 'h': 1200, 'resize': 'fit'}, 'small': {'w': 672, 'h': 680, 'resize': 'fit'}, 'large': {'w': 1581, 'h': 1600, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1112601850530930689, 'id_str': '1112601850530930689', 'indices': [152, 175], 'media_url': 'http://pbs.twimg.com/media/D3DBfP1WoAE7uNY.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D3DBfP1WoAE7uNY.jpg', 'url': 'https://t.co/sIT7tROGdS', 'display_url': 'pic.twitter.com/sIT7tROGdS', 'expanded_url': 'https://twitter.com/XTNVillanueva/status/1112601860781887489/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1186, 'h': 1200, 'resize': 'fit'}, 'small': {'w':  ...

# %%
import subprocess
import os

# %%
subprocess.call("./config.py", shell = True)
# Out:
# 1

# %%
consumer_key = os.environ['consumer_key']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-711c2a0c9b45> in <module>()
# ----> 1 consumer_key = os.environ['consumer_key']
#
# ~\Anaconda3\lib\os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'consumer_key'

# %%
import pyodbc

# %%
server = 'roundu.database.windows.net'
database = 'RoundU_DB'
username = 'roundu'
password = 'Barcelona2019'
driver= '{SQL Server}'
#driver= '{ODBC Driver 17 for SQL Server}'
cnxn = pyodbc.connect('DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)

cursor = cnxn.cursor()
cursor.execute("delete FROM dbo.users where USERS_ID='a'")
row = cursor.fetchone()
while row:
    print (str(row))
    row = cursor.fetchone()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-29-b2cf5d9037ea> in <module>()
#       9 cursor = cnxn.cursor()
#      10 cursor.execute("delete FROM dbo.users where USERS_ID='a'")
# ---> 11 row = cursor.fetchone()
#      12 while row:
#      13     print (str(row))
#
# ProgrammingError: No results.  Previous SQL was not a query.

# %%
cursor.execute("delete * from dbo.users")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-27-062436db83df> in <module>()
# ----> 1 cursor.execute("delete * from dbo.users")
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC SQL Server Driver][SQL Server]Incorrect syntax near '*'. (102) (SQLExecDirectW)")

# %%
def data_extract(json):
    """
    Extracts data from every tweet
    """
    msg_id = json["id"]
    msg_users_id = json["user"]["id"]
    msg_timestamp = json["created_at"]
    if "RT @" in json["text"]:
        if json["retweeted_status"]["truncated"]:
            msg_text = json["retweeted_status"]["extended_tweet"]["full_text"]
        else:
            msg_text = json["retweeted_status"]["text"]
    else:
        if json["truncated"]:
            msg_text = json["extended_tweet"]["full_text"]
        else:
            msg_text = json["text"]
    
    users_name = json["user"]["screen_name"]
    users_id = msg_users_id
    users_desc = json["user"]["description"]
    users_follows = json["user"]["friends_count"]
    users_followers = json["user"]["followers_count"]
    user_tweets = json["user"]["statuses_count"]

    return (str(msg_id), str(msg_users_id), msg_timestamp, msg_text, 
    users_name, users_id, users_desc, users_follows, users_followers, user_tweets)

# %%
data_extract(tw)
# Out:
# ('1113102791067795457',
#  '936233026660511744',
#  Timestamp('2019-04-02 15:36:00'),
#  "[#LaLiga 🇪🇸] La forme de Lionel #Messi avec le FC Barcelone : \n.\n.\n[#LaLiga 🇪🇸] Lionel Messi's vorm voor FC Barcelona:\n\n⚽⚽ vs Espanyol\n⚽⚽⚽ vs Betis\n⚽⚽🎯 vs Lyon\n🎯⚽ vs Vallecano https://t.co/RLHuBIYGdJ",
#  'REDsportsBE',
#  936233026660511744,
#  'REDsports provides stats and insights on sports. Focus on our Belgian teams and competitions, but driven by the passion for sports.',
#  67,
#  649,
#  6404)

# %%
for i in data_extract(tw):
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
